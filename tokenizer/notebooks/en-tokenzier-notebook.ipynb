# %%
def read_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = f.read()
        assert data, f"Файл {file_path} пустой или не удалось cчитать данные."
        return data
        
text = read_data('C:/Tokenizer/DataSets/en.txt')

# %%
import re

def clean_text(text):
    text = re.sub(r"[^a-z\s]", "", text.lower()) 
    text = ' '.join(text.split())
    return text
    
corpus = clean_text(text)

# %%
if corpus is not None:
    print("Первые 100 символов из анг:")
    print(corpus[:100])
# Out:
# Первые 100 символов из анг:
# stopping russia starts in syria washington dc the solution to the crisis in ukraine lies in part in

# %%
from collections import defaultdict

vocab = defaultdict(int)
for word in corpus.split():
    for char in word:
        vocab[char] += 1
    vocab['_ed'] += 1

# %%
print(len(vocab))
vocab
# Out:
# 27
# defaultdict(int,
#             {'s': 4793736,
#              't': 6573886,
#              'o': 5373890,
#              'p': 1593574,
#              'i': 5701556,
#              'n': 5450891,
#              'g': 1456995,
#              '_ed': 13746943,
#              'r': 4620693,
#              'u': 2049723,
#              'a': 5825433,
#              'y': 1118885,
#              'w': 1061333,
#              'h': 2969104,
#              'd': 2526262,
#              'c': 2586146,
#              'e': 8707030,
#              'l': 3086439,
#              'k': 407799,
#              'm': 1862158,
#              'f': 1482604,
#              'b': 1083111,
#              'v': 804839,
#              'j': 101585,
#              'x': 146008,
#              'q': 71929,
#              'z': 92544})

# %%
words = defaultdict(int)

for word in corpus.split():
    symbols = list(word) + ['_ed']
    words[' '.join(symbols)] += 1

# %%
for i, (key, value) in enumerate(words.items()):
    if i < 5:
        print(f"'{key}': {value}")
    else:
        break
# Out:
# 's t o p p i n g _ed': 215
# 'r u s s i a _ed': 8649
# 's t a r t s _ed': 331
# 'i n _ed': 305742
# 's y r i a _ed': 2903

# %%
def get_stats(words):
    pairs = defaultdict(int)
    for word, freq in words.items():
        symbols = word.split()
        for i in range(len(symbols) - 1):
            if symbols[i+1] != '_ed':
                pair = (symbols[i], symbols[i+1])
                pairs[pair] += freq
    return pairs

# %%
pairs = get_stats(words)
print(sorted(((v,k) for k,v in pairs.items()), reverse=True))
# Out:
# [(1744564, ('t', 'h')), (1480921, ('i', 'n')), (1321614, ('h', 'e')), (1154993, ('a', 'n')), (1108179, ('r', 'e')), (1055052, ('e', 'r')), (1037991, ('o', 'n')), (870594, ('a', 't')), (860007, ('e', 's')), (850211, ('e', 'n')), (825842, ('t', 'i')), (741413, ('o', 'r')), (697103, ('a', 'l')), (696409, ('n', 'd')), (693173, ('i', 't')), (682068, ('n', 't')), (673173, ('s', 't')), (669088, ('t', 'e')), (636678, ('i', 's')), (615880, ('a', 'r')), (603142, ('n', 'g')), (598975, ('t', 'o')), (578063, ('e', 'd')), (566500, ('h', 'a')), (548934, ('c', 'o')), (532193, ('v', 'e')), (506433, ('d', 'e')), (490804, ('i', 'o')), (480608, ('a', 's')), (465744, ('l', 'e')), (461600, ('i', 'c')), (461471, ('o', 'f')), (460539, ('s', 'e')), (457865, ('r', 'o')), (455772, ('l', 'i')), (455569, ('m', 'e')), (454984, ('r', 'i')), (450786, ('e', 'a')), (443401, ('o', 'u')), (425610, ('r', 'a')), (390796, ('n', 'e')), (369756, ('e', 'c')), (360771, ('c', 'e')), (354989, ('o', 'm')), (344939, ('n', 's')), (340238, ('s', 'i')), (339015, ('h', 'i')), (338282, ('l', 'l')), (337844, ('t', 'a')), (328692, ('c', 'a')), (316550, ('u', 'r')), (313523, ('m', 'a')), (310646, ('t', 'r')), (300385, ('n', 'o')), (298665, ('p', 'r')), (298455, ('u', 's')), (297277, ('c', 'h')), (295856, ('i', 'l')), (293221, ('b', 'e')), (290195, ('u', 'n')), (289183, ('n', 'a')), (282668, ('e', 'l')), (279377, ('p', 'o')), (275564, ('l', 'a')), (272697, ('f', 'o')), (270286, ('n', 'c')), (270065, ('p', 'e')), (267028, ('t', 's')), (262674, ('l', 'y')), (257979, ('u', 't')), (253629, ('d', 'i')), (250777, ('m', 'i')), (247628, ('r', 's')), (236417, ('c', 't')), (236210, ('g', 'e')), (235518, ('e', 'm')), (234687, ('a', 'c')), (232672, ('i', 'e')), (230882, ('s', 's')), (226849, ('l', 'o')), (225840, ('o', 'l')), (223926, ('i', 'a')), (222359, ('u', 'l')), (221891, ('m', 'o')), (219868, ('e', 't')), (218901, ('w', 'i')), (211600, ('o', 't')), (210771, ('n', 'i')), (208421, ('a', 'd')), (206614, ('h', 'o')), (204302, ('o', 'w')), (198744, ('e', 'e')), (196637, ('r', 't')), (194943, ('c', 'i')), (190708, ('s', 'o')), (190376, ('s', 'u')), (189428, ('o', 'p')), (188535, ('l', 'd')), (187629, ('i', 'm')), (177295, ('p', 'a')), (175513, ('i', 'r')), (173395, ('i', 'v')), (172870, ('w', 'e')), (172404, ('o', 's')), (167841, ('w', 'h')), (166873, ('f', 'i')), (166032, ('a', 'i')), (161707, ('e', 'v')), (159335, ('i', 'd')), (158035, ('m', 'p')), (151116, ('o', 'v')), (150977, ('v', 'i')), (149928, ('w', 'o')), (148303, ('k', 'e')), (146006, ('s', 'h')), (145829, ('i', 'g')), (144873, ('a', 'm')), (140982, ('w', 'a')), (140637, ('p', 'l')), (136609, ('a', 'b')), (136375, ('b', 'a')), (134790, ('t', 'y')), (132692, ('b', 'l')), (132196, ('b', 'u')), (128849, ('t', 'u')), (128378, ('r', 'y')), (125367, ('r', 'n')), (123993, ('g', 'r')), (123852, ('u', 'c')), (121906, ('c', 'r')), (119864, ('a', 'v')), (117276, ('a', 'g')), (116522, ('e', 'x')), (116233, ('f', 'r')), (113667, ('e', 'i')), (112215, ('g', 'h')), (110848, ('e', 'f')), (110648, ('r', 'u')), (107666, ('r', 'm')), (106136, ('f', 'e')), (104361, ('d', 'o')), (103402, ('a', 'p')), (103364, ('b', 'o')), (98548, ('c', 'u')), (98373, ('o', 'c')), (95572, ('g', 'i')), (94082, ('s', 'p')), (92475, ('o', 'o')), (92357, ('i', 'f')), (91901, ('a', 'y')), (91741, ('f', 'a')), (90679, ('g', 'o')), (90015, ('e', 'g')), (89421, ('c', 'l')), (86154, ('e', 'p')), (85778, ('b', 'y')), (83670, ('s', 'a')), (83405, ('r', 'd')), (83088, ('f', 'f')), (82939, ('o', 'd')), (81894, ('u', 'e')), (81751, ('g', 'a')), (81616, ('o', 'b')), (81397, ('l', 's')), (78863, ('r', 'g')), (78805, ('e', 'u')), (78314, ('p', 'p')), (78214, ('d', 'a')), (76661, ('r', 'l')), (75702, ('d', 'u')), (75022, ('b', 'i')), (73836, ('u', 'm')), (73581, ('d', 's')), (72763, ('p', 'u')), (71877, ('e', 'y')), (71577, ('l', 'u')), (71347, ('l', 't')), (70573, ('e', 'w')), (70412, ('m', 'u')), (68963, ('u', 'p')), (68391, ('a', 'k')), (68119, ('r', 'k')), (67957, ('v', 'a')), (67679 ...

# %%
top_pair = max(pairs, key=pairs.get)
top_pair
# Out:
# ('t', 'h')

# %%
def merge_vocab(pair, v_in):
    v_out = {}
    bigram = ' '.join(pair)
    pattern = re.compile(r'(?<!\S)' + re.escape(bigram) + r'(?!\S)')
    for word_in in v_in:
        word_out = pattern.sub(''.join(pair), word_in)
        v_out[word_out] = v_in[word_in]
    return v_out

# %%
vocab_size = 1000
num_merges = vocab_size - len(vocab)
for i in range(num_merges):
    pairs = get_stats(words)
    if not pairs:
        break
    best = max(pairs, key=pairs.get)
    vocab[''.join(best)] = pairs[best]
    words = merge_vocab(best, words)
    if i % 10 == 0:
        print(f'Итерация {i}: слияние {best}, размер словаря: {len(vocab)}')
print(f'Обучение завершено. Размер словаря: {len(vocab)}')
# Out:
# Итерация 0: слияние ('t', 'h'), размер словаря: 28
# Итерация 10: слияние ('s', 't'), размер словаря: 38
# Итерация 20: слияние ('i', 'c'), размер словаря: 48
# Итерация 30: слияние ('i', 'l'), размер словаря: 58
# Итерация 40: слияние ('th', 'at'), размер словаря: 68
# Итерация 50: слияние ('u', 't'), размер словаря: 78
# Итерация 60: слияние ('p', 'e'), размер словаря: 88
# Итерация 70: слияние ('re', 's'), размер словаря: 98
# Итерация 80: слияние ('k', 'e'), размер словаря: 108
# Итерация 90: слияние ('es', 's'), размер словаря: 118
# Итерация 100: слияние ('i', 'al'), размер словаря: 128
# Итерация 110: слияние ('p', 'ol'), размер словаря: 138
# Итерация 120: слияние ('l', 'i'), размер словаря: 148
# Итерация 130: слияние ('mo', 're'), размер словаря: 158
# Итерация 140: слияние ('ic', 'al'), размер словаря: 168
# Итерация 150: слияние ('the', 'ir'), размер словаря: 178
# Итерация 160: слияние ('i', 'a'), размер словаря: 188
# Итерация 170: слияние ('ch', 'in'), размер словаря: 198
# Итерация 180: слияние ('wor', 'ld'), размер словаря: 208
# Итерация 190: слияние ('o', 'ther'), размер словаря: 218
# Итерация 200: слияние ('c', 're'), размер словаря: 228
# Итерация 210: слияние ('w', 'ar'), размер словаря: 238
# Итерация 220: слияние ('at', 'ed'), размер словаря: 248
# Итерация 230: слияние ('pol', 'it'), размер словаря: 258
# Итерация 240: слияние ('k', 'ing'), размер словаря: 268
# Итерация 250: слияние ('mo', 'st'), размер словаря: 278
# Итерация 260: слияние ('a', 'ge'), размер словаря: 288
# Итерация 270: слияние ('le', 'ct'), размер словаря: 298
# Итерация 280: слияние ('en', 's'), размер словаря: 308
# Итерация 290: слияние ('sh', 'ould'), размер словаря: 318
# Итерация 300: слияние ('ac', 'k'), размер словаря: 328
# Итерация 310: слияние ('c', 'i'), размер словаря: 338
# Итерация 320: слияние ('wh', 'en'), размер словаря: 348
# Итерация 330: слияние ('a', 'de'), размер словаря: 358
# Итерация 340: слияние ('su', 'p'), размер словаря: 368
# Итерация 350: слияние ('f', 'ir'), размер словаря: 378
# Итерация 360: слияние ('publ', 'ic'), размер словаря: 388
# Итерация 370: слияние ('countr', 'y'), размер словаря: 398
# Итерация 380: слияние ('an', 'y'), размер словаря: 408
# Итерация 390: слияние ('in', 'st'), размер словаря: 418
# Итерация 400: слияние ('cau', 'se'), размер словаря: 428
# Итерация 410: слияние ('se', 'l'), размер словаря: 438
# Итерация 420: слияние ('ill', 'ion'), размер словаря: 448
# Итерация 430: слияние ('ag', 'ain'), размер словаря: 458
# Итерация 440: слияние ('in', 'to'), размер словаря: 468
# Итерация 450: слияние ('r', 'u'), размер словаря: 478
# Итерация 460: слияние ('e', 'lect'), размер словаря: 488
# Итерация 470: слияние ('c', 'er'), размер словаря: 498
# Итерация 480: слияние ('en', 'g'), размер словаря: 508
# Итерация 490: слияние ('ar', 'ly'), размер словаря: 518
# Итерация 500: слияние ('re', 'al'), размер словаря: 528
# Итерация 510: слияние ('i', 'ous'), размер словаря: 538
# Итерация 520: слияние ('government', 's'), размер словаря: 548
# Итерация 530: слияние ('su', 'm'), размер словаря: 558
# Итерация 540: слияние ('es', 'e'), размер словаря: 568
# Итерация 550: слияние ('iv', 'en'), размер словаря: 578
# Итерация 560: слияние ('su', 'l'), размер словаря: 588
# Итерация 570: слияние ('s', 's'), размер словаря: 598
# Итерация 580: слияние ('s', 'ign'), размер словаря: 608
# Итерация 590: слияние ('to', 'day'), размер словаря: 618
# Итерация 600: слияние ('prod', 'uct'), размер словаря: 628
# Итерация 610: слияние ('b', 'or'), размер словаря: 638
# Итерация 620: слияние ('re', 'as'), размер словаря: 648
# Итерация 630: слияние ('ter', 's'), размер словаря: 658
# Итерация 640: слияние ('plo', 'y'), размер словаря: 668
# Итерация 650: слияние ('ad', 'v'), размер словаря: 678
# Итерация 660: слияние ('u', 'se'), размер словаря: 688
# Итерация 670: слияние ('fore', 'ign'), размер словаря: 698
# Итерация 680: слияние ('e', 'as'), размер словаря: 708
# Итерация 690: слияние ('fa', 'il'), размер словаря: 718
# Итерация 700: слияние ('h', 'ist'), размер словаря: 728
# Итерация 710: слияние ('u', 'str'), размер словаря: 738
# Итерация 720: слияние ('il', 'y'), размер словаря: 748
# Итерация 730: слияние ('chin', 'ese'), размер словаря: 758
# Итерация 740: слияние ('de', 'mand'), размер словаря: 768
# Итерация 750: слияние ('s', 'ing'), размер словаря: 778
# Итерация 760: слияние ('mon', 'th'), размер словаря: 788
# Итерация 770: слияние ('im', 'es'), размер словаря: 798
# Итерация 780: слияние ('ab', 'l'), размер словаря: 808
# Итерация 790: слияние ('e', 't'), размер словаря: 818
# Итерация 800: слияние ('ro', 'ad'), размер словаря: 828
# Итерация 810: слияние ('r', 'ate'), размер словаря: 838
# Итерация 820: слияние ('a', 'ment'), размер словаря: 848
# Итерация 830: слияние ('cor', 'd'), размер словаря: 858
# Итерация 840: слияние ('mone', 'tary'), размер словаря: 868
# Итерация 850: слияние ('p', 'ast'), размер словаря: 878
# Итерация 860: слияние ('partic', 'ul'), размер словаря: 888
# Итерация 870: слияние ('ra', 'ther'), размер словаря: 898
# Итерация 880: слияние ('j', 'ob'), размер словаря: 908
# Итерация 890: слияние ('a', 'v'), размер словаря: 918
# Итерация 900: слияние ('sign', 'ific'), размер словаря: 928
# Итерация 910: слияние ('comm', 'it'), размер словаря: 938
# Итерация 920: слияние ('d', 'uring'), размер словаря: 948
# Итерация 930: слияние ('si', 'de'), размер словаря: 958
# Итерация 940: слияние ('cur', 'ren'), размер словаря: 968
# Итерация 950: слияние ('pr', 'of'), размер словаря: 978
# Итерация 960: слияние ('h', 'ou'), размер словаря: 988
# Итерация 970: слияние ('c', 'ul'), размер словаря: 998
# Обучение завершено. Размер словаря: 1000

# %%
vocab
# Out:
# defaultdict(int,
#             {'s': 4793736,
#              't': 6573886,
#              'o': 5373890,
#              'p': 1593574,
#              'i': 5701556,
#              'n': 5450891,
#              'g': 1456995,
#              '_ed': 13746943,
#              'r': 4620693,
#              'u': 2049723,
#              'a': 5825433,
#              'y': 1118885,
#              'w': 1061333,
#              'h': 2969104,
#              'd': 2526262,
#              'c': 2586146,
#              'e': 8707030,
#              'l': 3086439,
#              'k': 407799,
#              'm': 1862158,
#              'f': 1482604,
#              'b': 1083111,
#              'v': 804839,
#              'j': 101585,
#              'x': 146008,
#              'q': 71929,
#              'z': 92544,
#              'th': 1744564,
#              'in': 1480921,
#              'an': 1154993,
#              'the': 1139668,
#              're': 1108179,
#              'on': 1037991,
#              'at': 848723,
#              'er': 846127,
#              'en': 772314,
#              'al': 697103,
#              'st': 672547,
#              'or': 634457,
#              'it': 583653,
#              'es': 558683,
#              'is': 540714,
#              'ed': 512515,
#              'to': 504535,
#              'ar': 490235,
#              'ing': 475397,
#              'and': 463605,
#              'ic': 461600,
#              'of': 461068,
#              'ou': 440496,
#              'ion': 439976,
#              'as': 419742,
#              'ro': 362635,
#              'le': 337386,
#              'ent': 332373,
#              'de': 286125,
#              'om': 278316,
#              'il': 269210,
#              've': 265978,
#              'se': 255438,
#              'ch': 251813,
#              'ly': 246702,
#              'be': 238236,
#              'ct': 212641,
#              'for': 211967,
#              'con': 208053,
#              'ol': 198836,
#              'that': 197450,
#              'ation': 190962,
#              'im': 187629,
#              'su': 180926,
#              'un': 177694,
#              'ad': 176813,
#              'ce': 169323,
#              'wh': 167841,
#              'tr': 167573,
#              'no': 165379,
#              'ut': 165142,
#              'lo': 159103,
#              'ver': 158888,
#              'mo': 154873,
#              'us': 148862,
#              'ment': 146675,
#              'ld': 145878,
#              'ig': 145829,
#              'pro': 142480,
#              'ir': 142275,
#              'pe': 138493,
#              'am': 135713,
#              'ab': 134885,
#              'ies': 129744,
#              'com': 127661,
#              'ur': 127630,
#              'ge': 126802,
#              'are': 125645,
#              'we': 125543,
#              'id': 123407,
#              'res': 122551,
#              'ter': 120668,
#              'ill': 120048,
#              'po': 118623,
#              'ac': 118429,
#              'ne': 118323,
#              'ate': 116635,
#              'cou': 116114,
#              'wi': 108919,
#              'ul': 106392,
#              'ke': 102257,
#              'with': 101138,
#              'ex': 99534,
#              'ha': 99370,
#              'ers': 97753,
#              'em': 97742,
#              'ma': 95964,
#              'ist': 95793,
#              'ity': 95555,
#              'if': 90596,
#              'ess': 89994,
#              'so': 87871,
#              'not': 87535,
#              'but': 87442,
#              'ap': 86135,
#              'sh': 85748,
#              'by': 85292,
#              'over': 83873,
#              'te': 83864,
#              'ive': 83072,
#              'ial': 82413,
#              'all': 80927,
#              'ag': 80639,
#              'ts': 79277,
#              'wor': 78804,
#              'ther': 77825,
#              'iv': 77330,
#              'op': 77175,
#              'has': 75662,
#              'he': 74970,
#              'pol': 73969,
#              'coun': 73726,
#              'man': 72663,
#              'ay': 72323,
#              'its': 71848,
#              'have': 71746,
#              'ain': 71641,
#              'eu': 70657,
#              'one': 70388,
#              'ould': 70051,
#              'li': 69097,
#              'will': 68177,
#              'igh': 67700,
#              'econ': 66275,
#              'econom': 66169,
#              'pr': 66071,
#              'fe': 65306,
#              'str': 64479,
#              'out': 63792,
#              'qu': 63380,
#              'more': 62857,
#              'act': 61789,
#              'this': 61675,
#              'pl': 61218,
#              'por': 60726,
#              'cr': 60723,
#              'ions': 60217,
#              'rom': 60187,
#              'from': 59174,
#              'ans': 58377,
#              'ical': 57717,
#              'countr': 57192,
#              'par': 56530,
#              'cl': 56129,
#              'ren': 55960,
#              'euro': 55391,
#              'iz': 54992,
#              'ast': 54907,
#              'red': 54679,
#              'end': 54666,
#              'their': 54528,
#              'ant': 53187,
#              'ye': 52448,
#              'ind': 51874,
#              'ow': 51856,
#              'ong': 50833,
#              'per': 50168,
#              'ust': 47815,
#              'was': 46806,
#              'ev': 46795,
#              'ia': 46655,
#              'co': 46366,
#              'pres': 46009,
#              'me': 45980,
#              'ary': 45463,
#              'af': 45356,
#              'der': 45346,
#              'port': 44880,
#              'they': 44867,
#              'would': 44445,
#              'chin': 44027,
#              'ich': 43869,
#              'au': 43510,
#              'cial': 42926,
#              'overn': 42683,
#              'can': 42592,
#              'ra': 42530,
#              'govern': 42056,
#              'um': 41609,
#              'cent': 41556,
#              'world': 41320,
#              'gh': 41116,
#              'able': 40828,
#              'ome': 40475,
#              'nation': 40140,
#              'ef': 40083,
#              'ous': 39889,
#              'year': 39511,
#              'do': 39409,
#              'europe': 39262,
#              'other': 39196,
#              'pre': 38909,
#              'fin': 38663,
#              'low': 38548,
#              'than': 38483,
#              'fo': 38438,
#              'mar': 38369,
#              'row': 38045,
#              'part': 38038,
#              'new': 38037,
#              'cre': 38012,
#              'bal': 37879,
#              'vi': 37709,
#              'which': 37612,
#              'ates': 37524,
#              'ance': 37502,
#              'countries': 36783,
#              'ks': 36767,
#              'cur': 36767,
#              'government': 36709,
#              'war': 36644,
#              'ure': 36619,
#              'oun': 36481,
#              'form': 35820,
#              'now': 35796,
#              'ign': 35619,
#              'our': 35493,
#              'bo': 35456,
#              'ta': 35412,
#              'si': 35365,
#              'ated': 35269,
#              'economic': 35246,
#              'bl': 34951,
#              'pos': 34704,
#              'gr': 34418,
#              'reg': 34375,
#              'ough': 34244,
#              'inter': 33997,
#              'dis': 33634,
#              'go': 33631,
#              'polit': 33579,
#              'pt': 33527,
#              'll': 33324,
#              'national': 33135,
#              'cess': 33134,
#              'ight': 33120,
#              'ime': 32888,
#              'polic': 32717,
#              'ip': 32625,
#              'comm': 32524,
#              'king': 32299,
#              'el': 32127,
#              'ban': 31963,
#              'uct': 31908,
#              'many': 31880,
#              'ree': 31802,
#              'ations': 31713,
#              'lead': 31537,
#              'ble': 31487,
#              'ence': 31227,
#              'most': 31073,
#              'sy': 30939,
#              'grow': 30656,
#              'ud': 30636,
#              'been': 30256,
#              'ds': 29820,
#              'cont': 29621,
#              'min': 29616,
#              'ber': 29586,
#              'glo': 29476,
#              'age': 29104,
#              'uc': 28933,
#              'like': 28929,
#              'some': 28852,
#              'fa': 28819,
#              'global': 28721,
#              'ian': 28579,
#              'there': 28457,
#              'ors': 28273,
#              'rest': 28222,
#              'lect': 28115,
#              'ach': 27822,
#              'fic': 27799,
#              'come': 27672,
#              'br': 27665,
#              'who': 27354,
#              'ition': 27296,
#              'chan': 27155,
#              'ces': 26903,
#              'inte': 26860,
#              'ens': 26477,
#              'ine': 26436,
#              'ish': 26326,
#              'amer': 26160,
#              'his': 25956,
#              'ident': 25867,
#              'ile': 25851,
#              'ally': 25746,
#              'own': 25602,
#              'ger': 25594,
#              'should': 25591,
#              'could': 25384,
#              'ser': 25379,
#              'americ': 25331,
#              'only': 25208,
#              'int': 25173,
#              'reat': 25107,
#              'est': 25052,
#              'ple': 25038,
#              'such': 25009,
#              'ack': 24953,
#              'up': 24664,
#              'even': 24503,
#              'fr': 24380,
#              'also': 24195,
#              'whe': 24121,
#              'political': 24087,
#              'need': 24063,
#              'fl': 24058,
#              'lar': 24011,
#              'ci': 24000,
#              'long': 23975,
#              'sp': 23863,
#              'ty': 23798,
#              'ob': 23762,
#              'about': 23736,
#              'lop': 23691,
#              'ass': 23681,
#              'marke': 23621,
#              'wer': 23611,
#              'when': 23589,
#              'ire': 23588,
#              'velop': 23507,
#              'od': 23458,
#              'develop': 23421,
#              'under': 23417,
#              'years': 23352,
#              'tur': 23295,
#              'pu': 23282,
#              'ris': 23080,
#              'ade': 22978,
#              'vo': 22938,
#              'peop': 22936,
#              'ue': 22855,
#              'china': 22853,
#              'ting': 22848,
#              'fore': 22807,
#              'ities': 22795,
#              'ited': 22790,
#              'way': 22725,
#              'sup': 22710,
#              'what': 22582,
#              'finan': 22573,
#              'ism': 22561,
#              'publ': 22479,
#              'bet': 22295,
#              'ound': 22254,
#              'ility': 22069,
#              'vest': 22056,
#              'ted': 22039,
#              'fir': 22022,
#              'these': 21870,
#              'less': 21851,
#              'cal': 21749,
#              'gy': 21668,
#              'policy': 21667,
#              'ful': 21604,
#              'ative': 21543,
#              'growth': 21308,
#              'invest': 21234,
#              'public': 21139,
#              'ame': 21015,
#              'ital': 21011,
#              'high': 20729,
#              'cap': 20657,
#              'cor': 20624,
#              'people': 20620,
#              'cy': 20544,
#              'ener': 20494,
#              'power': 20474,
#              'country': 20403,
#              'ak': 20276,
#              'were': 20208,
#              'time': 20141,
#              'european': 20139,
#              'old': 19733,
#              'dec': 19545,
#              'lear': 19530,
#              'creas': 19516,
#              'may': 19418,
#              'any': 19327,
#              'them': 19280,
#              'ult': 19274,
#              'just': 19217,
#              'cau': 19198,
#              'ments': 19189,
#              'alth': 19103,
#              'ard': 19085,
#              'fect': 19048,
#              'increas': 18954,
#              'inst': 18899,
#              'financial': 18891,
#              'president': 18775,
#              'work': 18755,
#              'ps': 18681,
#              'tw': 18638,
#              'ho': 18632,
#              'rel': 18574,
#              'rent': 18506,
#              'while': 18448,
#              'cause': 18373,
#              'stem': 18340,
#              'ating': 18299,
#              'rus': 18126,
#              'je': 17945,
#              'international': 17908,
#              'must': 17889,
#              'day': 17817,
#              'ress': 17784,
#              'ms': 17782,
#              'sel': 17780,
#              'cris': 17698,
#              'states': 17663,
#              'sur': 17659,
#              'mu': 17614,
#              'ric': 17595,
#              'deb': 17587,
#              'put': 17543,
#              'ose': 17477,
#              'where': 17473,
#              'illion': 17463,
#              'interest': 17429,
#              'economy': 17296,
#              'ide': 17296,
#              'after': 17279,
#              'ict': 17234,
#              'mon': 17208,
#              'ory': 17191,
#              'med': 17184,
#              'prod': 17162,
#              'again': 17149,
#              'ice': 17147,
#              'had': 17124,
#              'system': 17101,
#              'demo': 17089,
#              'very': 17088,
#              'gu': 16933,
#              'sa': 16760,
#              'la': 16752,
#              'pect': 16732,
#              'into': 16719,
#              'main': 16561,
#              'incl': 16364,
#              'ace': 16327,
#              'comp': 16257,
#              'ution': 16240,
#              'fun': 16232,
#              'leaders': 16162,
#              'ced': 16146,
#              'democr': 16069,
#              'ru': 15895,
#              'much': 15892,
#              'ite': 15886,
#              'change': 15640,
#              'because': 15591,
#              'well': 15469,
#              'hu': 15455,
#              'crisis': 15445,
#              'ilit': 15445,
#              'united': 15381,
#              'elect': 15381,
#              'ices': 15379,
#              'des': 15371,
#              'ual': 15333,
#              'pon': 15141,
#              'mis': 15137,
#              'trans': 15119,
#              'cond': 15109,
#              'fact': 15085,
#              'read': 15079,
#              'cer': 15049,
#              'att': 15043,
#              'olo': 15005,
#              'struct': 15004,
#              'inde': 15001,
#              'ific': 14827,
#              'first': 14826,
#              'ep': 14812,
#              'ject': 14767,
#              'state': 14676,
#              'eng': 14643,
#              'dif': 14603,
#              'nor': 14552,
#              'vie': 14532,
#              'add': 14507,
#              'ics': 14497,
#              'trade': 14388,
#              'bas': 14383,
#              'plo': 14364,
#              'ists': 14337,
#              'arly': 14259,
#              'minist': 14259,
#              'those': 14240,
#              'di': 14232,
#              'pul': 14215,
#              'far': 14186,
#              'thing': 14156,
#              'recent': 14145,
#              'ild': 14114,
#              'ization': 14089,
#              'real': 14088,
#              'ater': 14060,
#              'large': 14029,
#              'oc': 13966,
#              'stand': 13966,
#              'mone': 13953,
#              'trum': 13944,
#              'two': 13943,
#              'ving': 13919,
#              'ents': 13839,
#              'ious': 13837,
#              'milit': 13761,
#              'rough': 13633,
#              'ween': 13623,
#              'between': 13572,
#              'market': 13385,
#              'off': 13294,
#              'vers': 13266,
#              'bu': 13216,
#              'how': 13194,
#              'governments': 13180,
#              'support': 13099,
#              'popul': 13022,
#              'ability': 13006,
#              'sim': 12989,
#              'pa': 12948,
#              'acy': 12944,
#              'vent': 12943,
#              'ie': 12938,
#              'turn': 12928,
#              'sum': 12924,
#              'effect': 12922,
#              'ten': 12910,
#              'col': 12846,
#              'led': 12776,
#              'ives': 12752,
#              'imate': 12750,
#              'mem': 12734,
#              'cour': 12728,
#              'cons': 12666,
#              'ese': 12592,
#              'val': 12590,
#              'contin': 12586,
#              'respon': 12562,
#              'tech': 12561,
#              'social': 12533,
#              'too': 12505,
#              'proble': 12446,
#              'bus': 12391,
#              'military': 12331,
#              'iven': 12253,
#              'ise': 12252,
#              'then': 12246,
#              'ize': 12219,
#              'remain': 12194,
#              'gener': 12190,
#              'hel': 12169,
#              'set': 12158,
#              'ince': 12147,
#              'serv': 12102,
#              'sul': 12077,
#              'atic': 12027,
#              'bank': 12013,
#              'includ': 11984,
#              'centr': 11968,
#              'leg': 11962,
#              'sub': 11961,
#              'last': 11958,
#              'both': 11930,
#              'import': 11873,
#              'ss': 11869,
#              'against': 11856,
#              'secur': 11852,
#              'dr': 11812,
#              'get': 11803,
#              'requ': 11767,
#              'tax': 11704,
#              'sure': 11685,
#              'exam': 11628,
#              'debt': 11621,
#              'sign': 11612,
#              'prote': 11565,
#              'prov': 11545,
#              'cas': 11544,
#              'jor': 11515,
#              'west': 11498,
#              'vel': 11470,
#              'health': 11436,
#              'capital': 11428,
#              'cost': 11308,
#              'today': 11305,
#              'ort': 11249,
#              'ko': 11239,
#              'through': 11193,
#              'contr': 11193,
#              'commun': 11133,
#              'infl': 11127,
#              'lim': 11127,
#              'self': 11093,
#              'ized': 11076,
#              'product': 11045,
#              'ward': 11027,
#              'car': 11022,
#              'ied': 10998,
#              'spe': 10991,
#              'ons': 10982,
#              'ann': 10905,
#              'current': 10905,
#              'pend': 10905,
#              'ph': 10905,
#              'bor': 10888,
#              'down': 10886,
#              'reform': 10874,
#              'ref': 10867,
#              'vol': 10808,
#              'uring': 10800,
#              'techn': 10787,
#              'major': 10773,
#              'does': 10733,
#              'development': 10712,
#              'reas': 10710,
#              'gan': 10686,
#              'instit': 10672,
#              'ben': 10666,
#              'human': 10654,
#              'great': 10650,
#              'issu': 10646,
#              'resul': 10637,
#              'ential': 10625,
#              'mand': 10624,
#              'ters': 10611,
#              'partic': 10610,
#              'ready': 10572,
#              'strate': 10542,
#              'chinas': 10541,
#              'tar': 10533,
#              'ext': 10518,
#              'since': 10514,
#              'land': 10506,
#              'afric': 10479,
#              'ploy': 10471,
#              'iran': 10470,
#              'help': 10467,
#              'security': 10450,
#              'seem': 10435,
#              'call': 10421,
#              'ures': 10409,
#              'fund': 10391,
#              'sol': 10346,
#              'central': 10299,
#              'adv': 10297,
#              'cus': 10251,
#              'key': 10243,
#              'tary': 10236,
#              'als': 10233,
#              'ves': 10173,
#              'view': 10160,
#              'back': 10159,
#              'term': 10135,
#              'chall': 10123,
#              'use': 10112,
#              'suc': 10102,
#              'example': 10091,
#              'jap': 10078,
#              'every': 10070,
#              'cho': 10044,
#              'including': 10026,
#              'make': 10024,
#              'investment': 10003,
#              'ply': 9987,
#              'foreign': 9976,
#              'ically': 9922,
#              'tain': 9906,
#              'likely': 9896,
#              'gress': 9887,
#              'markets': 9864,
#              'appro': 9809,
#              'sion': 9801,
#              'know': 9726,
#              'jo': 9702,
#              'eas': 9676,
#              'yet': 9665,
#              'become': 9641,
#              'soci': 9637,
#              'ption': 9609,
#              'still': 9602,
#              'iness': 9594,
#              'vir': 9593,
#              'banks': 9584,
#              'already': 9573,
#              'fail': 9563,
#              'tal': 9521,
#              'contro': 9514,
#              'utions': 9491,
#              'trump': 9475,
#              'fut': 9474,
#              'offic': 9463,
#              'ging': 9431,
#              'being': 9418,
#              'priv': 9364,
#              'hist': 9354,
#              'emer': 9318,
#              'arch': 9313,
#              'art': 9303,
#              'right': 9295,
#              'ared': 9294,
#              'mid': 9294,
#              'sia': 9290,
#              'east': 9285,
#              'ense': 9284,
#              'ustr': 9281,
#              'ians': 9262,
#              'region': 9253,
#              'policies': 9224,
#              'nat': 9219,
#              'indeed': 9210,
#              'technolo': 9164,
#              'ning': 9143,
#              'compe': 9126,
#              'bre': 9115,
#              'ily': 9102,
#              'see': 9098,
#              'ven': 9095,
#              'important': 9080,
#              'fol': 9051,
#              'employ': 9034,
#              'american': 9034,
#              'ri': 9027,
#              'oper': 9023,
#              'benef': 9009,
#              'chinese': 9007,
#              'future': 8993,
#              'qual': 8989,
#              'don': 8977,
#              'agree': 8960,
#              'sou': 8927,
#              'sible': 8917,
#              'pp': 8900,
#              'aim': 8884,
#              'ked': 8860,
#              'demand': 8852,
#              'vis': 8838,
#              'ending': 8836,
#              'level': 8763,
#              'russia': 8743,
#              'ration': 8735,
#              'boo': 8734,
#              'peri': 8698,
#              'business': 8673,
#              'russi': 8615,
#              'sing': 8612,
#              'clear': 8606,
#              'cut': 8580,
#              'germany': 8572,
#              'cred': 8565,
#              'hip': 8564,
#              'ys': 8551,
#              'pay': 8551,
#              'without': 8535,
#              'sect': 8535,
#              'month': 8521,
#              'take': 8520,
#              'risk': 8501,
#              'ca': 8500,
#              'same': 8495,
#              'lin': 8494,
#              'kill': 8449,
#              'pur': 8445,
#              'ib': 8430,
#              'threat': 8409,
#              'imes': 8389,
#              'law': 8386,
#              'economies': 8383,
#              'rates': 8368,
#              'diffe': 8356,
#              'educ': 8355,
#              'bon': 8330,
#              'ran': 8326,
#              'second': 8293,
#              'bers': 8280,
#              'abl': 8279,
#              'tle': 8240,
#              'dp': 8229,
#              'her': 8203,
#              'follow': 8193,
#              'ction': 8186,
#              'my': 8180,
#              'uk': 8167,
#              'worlds': 8160,
#              'del': 8156,
#              'et': 8153,
#              'ingly': 8149,
#              'climate': 8135,
#              'ness': 8108,
#              'japan': 8088,
#              'union': 8079,
#              'industr': 8075,
#              'fis': 8037,
#              'point': 7996,
#              'regul': 7990,
#              'road': 7989,
#              'ably': 7928,
#              'ins': 7916,
#              'ern': 7916,
#              'made': 7900,
#              'effor': 7896,
#              'lab': 7893,
#              'billion': 7883,
#              'har': 7880,
#              'did': 7827,
#              'rate': 7816,
#              'ades': 7808,
#              'isra': 7804,
#              'gdp': 7794,
#              'another': 7767,
#              'hold': 7763,
#              'fac': 7759,
#              'used': 7746,
#              'clo': 7745,
#              'strong': 7735,
#              'ament': 7729,
#              'good': 7726,
#              'success': 7719,
#              'exp': 7711,
#              'lif': 7698,
#              'though': 7691,
#              'tern': 7690,
#              'ail': 7681,
#              'ually': 7678,
#              'uclear': 7677,
#              'cord': 7665,
#              'might': 7664,
#              'gen': 7663,
#              'energy': 7642,
#              'dle': 7601,
#              'dire': 7595,
#              'pers': 7595,
#              'given': 7592,
#              'ti': 7582,
#              'fed': 7581,
#              'monetary': 7567,
#              'order': 7557,
#              'stain': 7554,
#              'accoun': 7544,
#              'fiscal': 7536,
#              'decl': 7531,
#              'open': 7519,
#              'ient': 7509,
#              'find': 7504,
#              'bar': 7494,
#              'past': 7477,
#              'ural': 7454,
#              'terr': 7453,
#              'ider': 7450,
#              'ights': 7447,
#              'nuclear': 7445,
#              'sustain': 7418,
#              'often': 7410,
#              'quest': 7407,
#              'project': 7401,
#              'particul': 7396,
#              'head': 7389,
#              'posed': 7379,
#              'dist': 7363,
#              'coming': 7357,
#              'middle': 7338,
#              'play': 7329,
#              'den': 7316,
#              'lit': 7315,
#              'compan': 7271,
#              'rather': 7267,
#              'better': 7262,
#              'action': 7261,
#              'before': 7248,
#              'income': 7232,
#              'brit': 7231,
#              'mat': 7217,
#              'thin': 7201,
#              'organ': 7182,
#              'problem': 7179,
#              'job': 7178,
#              'ways': 7172,
#              'ources': 7154,
#              'fall': 7152,
#              'nex': 7145,
#              'among': 7140,
#              'uel': 7117,
#              'pot': 7117,
#              'uce': 7096,
#              'education': 7093,
#              'av': 7091,
#              'isl': 7090,
#              'position': 7069,
#              'mak': 7067,
#              'beli': 7050,
#              'present': 7044,
#              'ators': 7043,
#              'cannot': 7042,
#              'thor': 7040,
#              'decis': 7035,
#              'signific': 7028,
#              'io': 7012,
#              'gram': 7009,
#              'employment': 6981,
#              'ged': 6979,
#              'cept': 6976,
#              'course': 6975,
#              'wom': 6969,
#              'cing': 6967,
#              'million': 6964,
#              'commit': 6960,
#              'certain': 6959,
#              'three': 6951,
#              'child': 6943,
#              'ues': 6922,
#              'expect': 6910,
#              'fur': 6908,
#              'ias': 6898,
#              'loo': 6890,
#              'ges': 6885,
#              'during': 6878,
#              'approach': 6873,
#              'labor': 6860,
#              'compet': 6858,
#              'rul': 6857,
#              'ship': 6853,
#              'fer': 6846,
#              'move': 6841,
#              'sm': 6840,
#              'program': 6808,
#              'side': 6788,
#              'ury': 6785,
#              'party': 6766,
#              'process': 6753,
#              'gest': 6749,
#              'loc': 6721,
#              'grou': 6714,
#              'care': 6712,
#              'dom': 6711,
#              'result': 6704,
#              'curren': 6702,
#              'happ': 6700,
#              'gn': 6698,
#              'effective': 6684,
#              'net': 6657,
#              'institutions': 6657,
#              'force': 6656,
#              'why': 6655,
#              'around': 6647,
#              'cit': 6640,
#              'prof': 6633,
#              'author': 6630,
#              'significant': 6626,
#              'cam': 6586,
#              'trad': 6579,
#              'appe': 6578,
#              'les': 6565,
#              'ages': 6560,
#              'peace': 6556,
#              'south': 6553,
#              'hou': 6552,
#              'companies': 6551,
#              'itional': 6534,
#              'countrys': 6532,
#              'americas': 6531,
#              'def': 6530,
#              'minister': 6526,
#              'america': 6514,
#              'mal': 6513,
#              'ying': 6511,
#              'cul': 6505,
#              'cover': 6502,
#              'ec': 6497})

# %%
print(len(vocab))
# Out:
# 1000

# %%
def build_token_mappings(vocab):
    tokens = list(vocab.keys())
    token_to_id = {token: idx for idx, token in enumerate(tokens)}
    id_to_token = {idx: token for idx, token in enumerate(tokens)}
    return token_to_id, id_to_token

token_to_id, id_to_token = build_token_mappings(vocab)

# %%
def add_special_tokens(token_to_id, id_to_token, special_tokens):
    for token in special_tokens:
        if token not in token_to_id:
            idx = len(token_to_id)
            token_to_id[token] = idx
            id_to_token[idx] = token

special_tokens = ['<start>', '<end>', '<unk>', '<pad>']
add_special_tokens(token_to_id, id_to_token, special_tokens)

print(f"\nДобавлены специальные токены. Размер словаря token_to_id: {len(token_to_id)}")
# Out:
# Добавлены специальные токены. Размер словаря token_to_id: 1004

# %%
import json
import os

output_dir = "C:/Tokenizer/Vocab/EnVocab" 

os.makedirs(output_dir, exist_ok=True)

with open(os.path.join(output_dir, 'token_to_id.json'), 'w', encoding='utf-8') as out_file:
    json.dump(token_to_id, out_file, indent=6, ensure_ascii=False)

with open(os.path.join(output_dir, 'id_to_token.json'), 'w', encoding='utf-8') as out_file:
    json.dump(id_to_token, out_file, indent=6, ensure_ascii=False)

print(f"Словари token_to_id и id_to_token сохранены в {output_dir}")
# Out:
# Словари token_to_id и id_to_token сохранены в C:/Tokenizer/Vocab/EnVocab

# %%
def tokenize_word(word, vocab):
    symbols = list(word) + ['_ed']  
    i = 0
    tokens = []
    while i < len(symbols):
        j = len(symbols)
        found = False
        while j > i:
            substring = ''.join(symbols[i:j])
            if substring in vocab:
                tokens.append(substring)
                i = j
                found = True
                break
            else:
                j -= 1
        if not found:
            tokens.append('<unk>')
            i += 1
    return tokens

# %%
def encode_text(text, token_to_id, vocab):
    token_ids = []
    for word in text.split():
        word_tokens = tokenize_word(word, vocab)
        for token in word_tokens:
            token_id = token_to_id.get(token)
            if token_id is not None:
                token_ids.append(token_id)
            else:
                token_ids.append(token_to_id.get('<unk>'))
    return token_ids

# %%
def decode_ids(token_ids, id_to_token):
    tokens = [id_to_token.get(token_id, '<unk>') for token_id in token_ids]
    words = []
    word = ''
    for token in tokens:
        if token == '_ed':
            words.append(word)
            word = ''
        elif token not in ['<start>', '<end>', '<pad>']:
            word += token
    if word:
        words.append(word)
    return ' '.join(words)

# %%
test_text = "I study in technical university, because i want to be a programmer"
test_text = clean_text(test_text)

# %%
encoded_ids = encode_text(test_text, token_to_id, vocab)
print("\nКодированные идентификаторы:")
print(encoded_ids)
# Out:
# Кодированные идентификаторы:
# [4, 7, 37, 280, 11, 7, 28, 7, 643, 167, 7, 71, 126, 8, 246, 340, 7, 481, 7, 4, 7, 12, 178, 7, 43, 7, 62, 7, 10, 7, 956, 190, 8, 7]

# %%
decoded_text = decode_ids(encoded_ids, id_to_token)
print("\nДекодированный текст:")
print(decoded_text)
# Out:
# Декодированный текст:
# i study in technical university because i want to be a programmer
