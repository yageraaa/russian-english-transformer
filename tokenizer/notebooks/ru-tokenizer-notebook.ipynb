# %%
def read_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = f.read()
        assert data, f"Файл {file_path} пустой или не удалось cчитать данные."
        return data

text = read_data('C:/Tokenizer/DataSets/ru.txt')

# %%
import re

def clean_text(text):
    text = re.sub(r"[^а-яё\s]", "", text.lower())
    text = ' '.join(text.split())
    return text

corpus = clean_text(text)

# %%
if corpus is not None:
    print("Первые 100 символов из ру:")
    print(corpus[:100])
# Out:
# Первые 100 символов из ру:
# я думал я буду читать те свои стихи которые связаны с темой юности и зрелости я даже немного удивилс

# %%
from collections import defaultdict

vocab = defaultdict(int)
for word in corpus.split():
    for char in word:
        vocab[char] += 1
    vocab['_ed'] += 1

# %%
print(len(vocab))
vocab
# Out:
# 34
# defaultdict(int,
#             {'я': 342793,
#              '_ed': 3064170,
#              'д': 505746,
#              'у': 397444,
#              'м': 640711,
#              'а': 1251411,
#              'л': 675358,
#              'б': 268953,
#              'ч': 272410,
#              'и': 1249335,
#              'т': 1200315,
#              'ь': 318961,
#              'е': 1380256,
#              'с': 861114,
#              'в': 702425,
#              'о': 1867683,
#              'х': 161763,
#              'к': 515989,
#              'р': 728335,
#              'ы': 371311,
#              'з': 279298,
#              'н': 1071319,
#              'й': 180365,
#              'ю': 131659,
#              'ж': 163408,
#              'г': 251697,
#              'п': 435103,
#              'щ': 63687,
#              'ш': 108749,
#              'ё': 48462,
#              'ц': 66405,
#              'э': 112219,
#              'ф': 44082,
#              'ъ': 4417})

# %%
words = defaultdict(int)

for word in corpus.split():
    symbols = list(word) + ['_ed']
    words[' '.join(symbols)] += 1

# %%
for i, (key, value) in enumerate(words.items()):
    if i < 5:
        print(f"'{key}': {value}")
    else:
        break
# Out:
# 'я _ed': 51449
# 'д у м а л _ed': 415
# 'б у д у _ed': 645
# 'ч и т а т ь _ed': 254
# 'т е _ed': 1781

# %%
def get_stats(words):
    pairs = defaultdict(int)
    for word, freq in words.items():
        symbols = word.split()
        for i in range(len(symbols) - 1):
            if symbols[i+1] != '_ed':
                pair = (symbols[i], symbols[i+1])
                pairs[pair] += freq
    return pairs

# %%
pairs = get_stats(words)
print(sorted(((v,k) for k,v in pairs.items()), reverse=True))
# Out:
# [(313608, ('т', 'о')), (231425, ('с', 'т')), (204957, ('н', 'о')), (204786, ('н', 'а')), (175042, ('н', 'и')), (165335, ('е', 'н')), (163421, ('п', 'о')), (162727, ('р', 'а')), (155561, ('к', 'о')), (150145, ('р', 'о')), (139773, ('о', 'т')), (139714, ('н', 'е')), (138165, ('т', 'ь')), (136865, ('о', 'в')), (136482, ('л', 'и')), (136475, ('п', 'р')), (125513, ('т', 'е')), (121966, ('т', 'а')), (121174, ('е', 'т')), (117139, ('о', 'с')), (116513, ('о', 'л')), (114543, ('р', 'е')), (114230, ('в', 'о')), (112119, ('в', 'а')), (110807, ('о', 'р')), (110454, ('к', 'а')), (109239, ('е', 'р')), (109214, ('г', 'о')), (106537, ('д', 'е')), (106124, ('е', 'с')), (105025, ('о', 'м')), (101762, ('и', 'т')), (100594, ('а', 'т')), (100590, ('о', 'д')), (100580, ('а', 'л')), (98860, ('а', 'н')), (97348, ('м', 'е')), (96354, ('о', 'г')), (94823, ('о', 'н')), (94654, ('л', 'ь')), (94277, ('е', 'л')), (93437, ('м', 'о')), (92672, ('л', 'е')), (91480, ('э', 'т')), (91074, ('е', 'м')), (91063, ('т', 'и')), (87906, ('а', 'к')), (86689, ('р', 'и')), (85900, ('о', 'б')), (85577, ('н', 'ы')), (84957, ('д', 'а')), (84278, ('л', 'о')), (80137, ('л', 'а')), (78364, ('ч', 'т')), (77204, ('а', 'с')), (76582, ('з', 'а')), (76127, ('в', 'е')), (70522, ('ч', 'е')), (70407, ('и', 'м')), (69556, ('и', 'н')), (65099, ('а', 'м')), (64772, ('м', 'и')), (63242, ('с', 'я')), (63177, ('д', 'о')), (62913, ('и', 'л')), (62885, ('о', 'й')), (62341, ('ж', 'е')), (62206, ('и', 'с')), (61747, ('т', 'р')), (60914, ('с', 'о')), (59820, ('б', 'ы')), (58997, ('б', 'о')), (58962, ('с', 'к')), (58915, ('и', 'з')), (58870, ('д', 'и')), (58580, ('а', 'з')), (58420, ('м', 'ы')), (58378, ('в', 'и')), (58049, ('м', 'а')), (57898, ('е', 'д')), (57507, ('и', 'е')), (57015, ('в', 'ы')), (56337, ('с', 'е')), (55907, ('т', 'в')), (53101, ('с', 'л')), (51176, ('к', 'и')), (50291, ('и', 'я')), (48930, ('а', 'в')), (48606, ('е', 'й')), (47079, ('н', 'н')), (46759, ('р', 'у')), (45539, ('о', 'ж')), (42127, ('а', 'е')), (41904, ('и', 'х')), (40084, ('в', 'с')), (39742, ('л', 'я')), (39598, ('а', 'р')), (39511, ('ч', 'а')), (38542, ('о', 'е')), (37996, ('х', 'о')), (37858, ('и', 'в')), (37755, ('с', 'п')), (37354, ('м', 'у')), (36894, ('и', 'к')), (36826, ('ь', 'н')), (36612, ('п', 'е')), (36399, ('т', 'с')), (36225, ('ы', 'е')), (35870, ('з', 'н')), (35836, ('о', 'к')), (35825, ('е', 'г')), (35556, ('р', 'ы')), (34664, ('о', 'ч')), (34526, ('ч', 'и')), (34090, ('а', 'ю')), (33981, ('о', 'з')), (33832, ('д', 'у')), (33169, ('е', 'к')), (33097, ('ш', 'е')), (33092, ('и', 'р')), (33046, ('н', 'т')), (32465, ('д', 'н')), (32376, ('с', 'и')), (31205, ('ж', 'н')), (31117, ('ц', 'и')), (30302, ('и', 'и')), (30254, ('и', 'ч')), (30185, ('и', 'д')), (30162, ('с', 'ь')), (30017, ('а', 'я')), (28910, ('л', 'ю')), (28834, ('ы', 'х')), (28822, ('у', 'д')), (28758, ('н', 'у')), (28734, ('а', 'д')), (28441, ('с', 'а')), (28113, ('м', 'н')), (28017, ('п', 'а')), (27760, ('о', 'п')), (27346, ('т', 'ы')), (27206, ('ж', 'и')), (27126, ('ы', 'л')), (27059, ('я', 'т')), (26973, ('ю', 'т')), (26956, ('ы', 'й')), (26428, ('у', 'ч')), (26365, ('к', 'т')), (26224, ('с', 'м')), (26150, ('н', 'я')), (25858, ('у', 'т')), (25784, ('т', 'у')), (25252, ('а', 'ж')), (25237, ('ш', 'и')), (24848, ('к', 'р')), (24834, ('щ', 'е')), (24640, ('а', 'б')), (24400, ('б', 'е')), (24170, ('г', 'д')), (24165, ('у', 'ю')), (23851, ('г', 'и')), (23572, ('к', 'у')), (22842, ('н', 'ь')), (22696, ('и', 'й')), (22508, ('л', 'у')), (22400, ('т', 'н')), (21935, ('ы', 'м')), (21899, ('е', 'в')), (21397, ('в', 'л')), (21392, ('г', 'р')), (21144, ('г', 'а')), (20989, ('ч', 'н')), (20661, ('в', 'н')), (20517, ('о', 'и')), (20512, ('б', 'р')), (20497, ('с', 'в')), (20416, ('щ', 'и')), (20408, ('а', 'ш')), (20377, ('у', 'ж')), (20092, ('а', 'ч')), (19822, ('з', 'д')), (19566, ('е', 'ч')), (19508, ('с', 'с')), (19440, ('д', 'л')), (19344, ('з', 'о')), (19115, ('е', 'з')), (19038, ('с', 'н')), (19032, ('е', 'е')), (18945, ('у', 'м')), (18911, ('у', 'с ...

# %%
top_pair = max(pairs, key=pairs.get)
top_pair
# Out:
# ('т', 'о')

# %%
def merge_vocab(pair, v_in):
    v_out = {}
    bigram = ' '.join(pair)
    pattern = re.compile(r'(?<!\S)' + re.escape(bigram) + r'(?!\S)')
    for word_in in v_in:
        word_out = pattern.sub(''.join(pair), word_in)
        v_out[word_out] = v_in[word_in]
    return v_out

# %%
vocab_size = 1000
num_merges = vocab_size - len(vocab)
for i in range(num_merges):
    pairs = get_stats(words)
    if not pairs:
        break
    best = max(pairs, key=pairs.get)
    vocab[''.join(best)] = pairs[best]
    words = merge_vocab(best, words)
    if i % 10 == 0:
        print(f'Итерация {i}: слияние {best}, размер словаря: {len(vocab)}')
print(f'Обучение завершено. Размер словаря: {len(vocab)}')
# Out:
# Итерация 0: слияние ('т', 'о'), размер словаря: 35
# Итерация 10: слияние ('л', 'и'), размер словаря: 45
# Итерация 20: слияние ('л', 'ь'), размер словаря: 55
# Итерация 30: слияние ('в', 'е'), размер словаря: 65
# Итерация 40: слияние ('п', 'ро'), размер словаря: 75
# Итерация 50: слияние ('р', 'у'), размер словаря: 85
# Итерация 60: слияние ('р', 'ы'), размер словаря: 95
# Итерация 70: слияние ('ни', 'я'), размер словаря: 105
# Итерация 80: слияние ('ст', 'и'), размер словаря: 115
# Итерация 90: слияние ('л', 'у'), размер словаря: 125
# Итерация 100: слияние ('и', 'с'), размер словаря: 135
# Итерация 110: слияние ('б', 'у'), размер словаря: 145
# Итерация 120: слияние ('с', 'у'), размер словаря: 155
# Итерация 130: слияние ('бо', 'ль'), размер словаря: 165
# Итерация 140: слияние ('д', 'ы'), размер словаря: 175
# Итерация 150: слияние ('ст', 'ра'), размер словаря: 185
# Итерация 160: слияние ('пе', 'р'), размер словаря: 195
# Итерация 170: слияние ('е', 'го'), размер словаря: 205
# Итерация 180: слияние ('хо', 'ди'), размер словаря: 215
# Итерация 190: слияние ('на', 'я'), размер словаря: 225
# Итерация 200: слияние ('ро', 'в'), размер словаря: 235
# Итерация 210: слияние ('ф', 'и'), размер словаря: 245
# Итерация 220: слияние ('вс', 'ё'), размер словаря: 255
# Итерация 230: слияние ('по', 'ль'), размер словаря: 265
# Итерация 240: слияние ('по', 'тому'), размер словаря: 275
# Итерация 250: слияние ('со', 'зда'), размер словаря: 285
# Итерация 260: слияние ('ют', 'ся'), размер словаря: 295
# Итерация 270: слияние ('по', 'сле'), размер словаря: 305
# Итерация 280: слияние ('к', 'ти'), размер словаря: 315
# Итерация 290: слияние ('те', 'х'), размер словаря: 325
# Итерация 300: слияние ('сто', 'я'), размер словаря: 335
# Итерация 310: слияние ('и', 'м'), размер словаря: 345
# Итерация 320: слияние ('это', 'т'), размер словаря: 355
# Итерация 330: слияние ('к', 'ры'), размер словаря: 365
# Итерация 340: слияние ('про', 'бле'), размер словаря: 375
# Итерация 350: слияние ('ва', 'с'), размер словаря: 385
# Итерация 360: слияние ('к', 'ру'), размер словаря: 395
# Итерация 370: слияние ('б', 'я'), размер словаря: 405
# Итерация 380: слияние ('при', 'мер'), размер словаря: 415
# Итерация 390: слияние ('к', 'лю'), размер словаря: 425
# Итерация 400: слияние ('ка', 'р'), размер словаря: 435
# Итерация 410: слияние ('н', 'т'), размер словаря: 445
# Итерация 420: слияние ('это', 'й'), размер словаря: 455
# Итерация 430: слияние ('ре', 'з'), размер словаря: 465
# Итерация 440: слияние ('э', 'та'), размер словаря: 475
# Итерация 450: слияние ('по', 'ня'), размер словаря: 485
# Итерация 460: слияние ('мог', 'ут'), размер словаря: 495
# Итерация 470: слияние ('вы', 'х'), размер словаря: 505
# Итерация 480: слияние ('пер', 'ь'), размер словаря: 515
# Итерация 490: слияние ('до', 'в'), размер словаря: 525
# Итерация 500: слияние ('до', 'ста'), размер словаря: 535
# Итерация 510: слияние ('спо', 'соб'), размер словаря: 545
# Итерация 520: слияние ('т', 'ру'), размер словаря: 555
# Итерация 530: слияние ('спаси', 'бо'), размер словаря: 565
# Итерация 540: слияние ('само', 'м'), размер словаря: 575
# Итерация 550: слияние ('р', 'т'), размер словаря: 585
# Итерация 560: слияние ('про', 'е'), размер словаря: 595
# Итерация 570: слияние ('жиз', 'нь'), размер словаря: 605
# Итерация 580: слияние ('не', 'го'), размер словаря: 615
# Итерация 590: слияние ('на', 'зыва'), размер словаря: 625
# Итерация 600: слияние ('ка', 'н'), размер словаря: 635
# Итерация 610: слияние ('но', 'сти'), размер словаря: 645
# Итерация 620: слияние ('коне', 'чно'), размер словаря: 655
# Итерация 630: слияние ('ва', 'л'), размер словаря: 665
# Итерация 640: слияние ('челове', 'к'), размер словаря: 675
# Итерация 650: слияние ('к', 'ри'), размер словаря: 685
# Итерация 660: слияние ('об', 'е'), размер словаря: 695
# Итерация 670: слияние ('да', 'ва'), размер словаря: 705
# Итерация 680: слияние ('ве', 'ро'), размер словаря: 715
# Итерация 690: слияние ('вре', 'мени'), размер словаря: 725
# Итерация 700: слияние ('к', 'ту'), размер словаря: 735
# Итерация 710: слияние ('ем', 'ся'), размер словаря: 745
# Итерация 720: слияние ('суще', 'ству'), размер словаря: 755
# Итерация 730: слияние ('о', 'г'), размер словаря: 765
# Итерация 740: слияние ('чески', 'е'), размер словаря: 775
# Итерация 750: слияние ('необ', 'ходи'), размер словаря: 785
# Итерация 760: слияние ('пра', 'в'), размер словаря: 795
# Итерация 770: слияние ('сво', 'и'), размер словаря: 805
# Итерация 780: слияние ('которо', 'е'), размер словаря: 815
# Итерация 790: слияние ('инте', 'р'), размер словаря: 825
# Итерация 800: слияние ('кото', 'рую'), размер словаря: 835
# Итерация 810: слияние ('ка', 'ми'), размер словаря: 845
# Итерация 820: слияние ('ко', 'ли'), размер словаря: 855
# Итерация 830: слияние ('н', 'к'), размер словаря: 865
# Итерация 840: слияние ('ли', 'бо'), размер словаря: 875
# Итерация 850: слияние ('по', 'те'), размер словаря: 885
# Итерация 860: слияние ('сво', 'ей'), размер словаря: 895
# Итерация 870: слияние ('ска', 'я'), размер словаря: 905
# Итерация 880: слияние ('сво', 'ю'), размер словаря: 915
# Итерация 890: слияние ('то', 'р'), размер словаря: 925
# Итерация 900: слияние ('сте', 'й'), размер словаря: 935
# Итерация 910: слияние ('ф', 'у'), размер словаря: 945
# Итерация 920: слияние ('же', 'тся'), размер словаря: 955
# Итерация 930: слияние ('ку', 'ль'), размер словаря: 965
# Итерация 940: слияние ('ма', 'ти'), размер словаря: 975
# Итерация 950: слияние ('гра', 'ни'), размер словаря: 985
# Итерация 960: слияние ('та', 'кое'), размер словаря: 995
# Обучение завершено. Размер словаря: 1000

# %%
vocab
# Out:
# defaultdict(int,
#             {'я': 342793,
#              '_ed': 3064170,
#              'д': 505746,
#              'у': 397444,
#              'м': 640711,
#              'а': 1251411,
#              'л': 675358,
#              'б': 268953,
#              'ч': 272410,
#              'и': 1249335,
#              'т': 1200315,
#              'ь': 318961,
#              'е': 1380256,
#              'с': 861114,
#              'в': 702425,
#              'о': 1867683,
#              'х': 161763,
#              'к': 515989,
#              'р': 728335,
#              'ы': 371311,
#              'з': 279298,
#              'н': 1071319,
#              'й': 180365,
#              'ю': 131659,
#              'ж': 163408,
#              'г': 251697,
#              'п': 435103,
#              'щ': 63687,
#              'ш': 108749,
#              'ё': 48462,
#              'ц': 66405,
#              'э': 112219,
#              'ф': 44082,
#              'ъ': 4417,
#              'то': 313608,
#              'но': 204957,
#              'на': 204786,
#              'ст': 198307,
#              'ни': 175042,
#              'по': 163421,
#              'ра': 162727,
#              'ко': 155561,
#              'ро': 150145,
#              'не': 139714,
#              'ли': 136482,
#              'ре': 114543,
#              'во': 114230,
#              'ва': 112119,
#              'те': 111986,
#              'ть': 110900,
#              'ка': 110454,
#              'го': 109214,
#              'де': 106537,
#              'ме': 97348,
#              'ль': 94654,
#              'мо': 93437,
#              'ле': 92672,
#              'ри': 86689,
#              'та': 86589,
#              'ны': 85577,
#              'да': 84957,
#              'ло': 84278,
#              'ла': 80137,
#              'за': 76582,
#              'ве': 76127,
#              'что': 75915,
#              'это': 72597,
#              'че': 70522,
#              'ми': 64772,
#              'ти': 63885,
#              'ся': 63242,
#              'до': 63177,
#              'же': 62341,
#              'со': 60914,
#              'про': 60559,
#              'бы': 59820,
#              'бо': 58997,
#              'ди': 58870,
#              'мы': 58420,
#              'ви': 58378,
#              'ма': 58049,
#              'вы': 57015,
#              'се': 56337,
#              'ки': 51176,
#              'ру': 46759,
#              'из': 44658,
#              'ля': 39742,
#              'ча': 39511,
#              'об': 38350,
#              'хо': 37968,
#              'ет': 37805,
#              'му': 37354,
#              'пе': 36431,
#              'при': 36210,
#              'ры': 35556,
#              'ста': 35377,
#              'чи': 34520,
#              'ду': 33832,
#              'сто': 33118,
#              'ше': 32921,
#              'си': 32300,
#              'от': 31127,
#              'ци': 31093,
#              'ние': 30510,
#              'ния': 30359,
#              'сь': 30162,
#              'кото': 29428,
#              'раз': 29044,
#              'лю': 28910,
#              'ну': 28758,
#              'са': 28441,
#              'па': 28017,
#              'как': 27337,
#              'сть': 27265,
#              'сти': 27171,
#              'мен': 27124,
#              'ши': 25155,
#              'ще': 24681,
#              'ты': 24653,
#              'ют': 24031,
#              'ги': 23836,
#              'ку': 23312,
#              'пре': 22895,
#              'все': 22834,
#              'лу': 22508,
#              'бе': 22055,
#              'га': 21144,
#              'так': 21027,
#              'нь': 20987,
#              'льно': 20747,
#              'жи': 20608,
#              'щи': 20416,
#              'жно': 20233,
#              'ско': 20140,
#              'ис': 19485,
#              'зна': 19428,
#              'гда': 19201,
#              'которы': 18800,
#              'ные': 18717,
#              'ем': 18683,
#              'ту': 18494,
#              'они': 18420,
#              'це': 18391,
#              'нно': 18384,
#              'бу': 17607,
#              'он': 17563,
#              'ных': 17432,
#              'ня': 16386,
#              'сле': 16054,
#              'ин': 15861,
#              'для': 15701,
#              'вать': 15330,
#              'сли': 15291,
#              'дела': 15278,
#              'су': 15188,
#              'ска': 14862,
#              'пи': 14255,
#              'би': 14173,
#              'ски': 14146,
#              'вер': 14103,
#              'когда': 14097,
#              'пра': 13978,
#              'ство': 13885,
#              'може': 13626,
#              'боль': 13575,
#              'ву': 13469,
#              'ный': 13374,
#              'мно': 13327,
#              'сте': 13116,
#              'ря': 12868,
#              'дру': 12774,
#              'ется': 12695,
#              'ша': 12622,
#              'если': 12561,
#              'ды': 12544,
#              'их': 12487,
#              'сво': 12437,
#              'эти': 12258,
#              'лько': 12204,
#              'жа': 12174,
#              'рабо': 12144,
#              'воз': 12036,
#              'рас': 11975,
#              'чно': 11691,
#              'стра': 11519,
#              'ор': 11468,
#              'дей': 11425,
#              'ться': 11366,
#              'тся': 11361,
#              'ком': 11329,
#              'чтобы': 11274,
#              'пу': 11208,
#              'она': 11195,
#              'ба': 11156,
#              'пер': 11153,
#              'зы': 11138,
#              'под': 11053,
#              'гра': 11013,
#              'ке': 10959,
#              'том': 10940,
#              'или': 10872,
#              'од': 10792,
#              'можно': 10747,
#              'пере': 10551,
#              'его': 10344,
#              'дол': 10288,
#              'мог': 10249,
#              'которые': 9836,
#              'оче': 9820,
#              'меня': 9760,
#              'вс': 9716,
#              'зо': 9711,
#              'вре': 9708,
#              'вот': 9681,
#              'ходи': 9670,
#              'стве': 9601,
#              'есть': 9460,
#              'кон': 9450,
#              'вля': 9433,
#              'мне': 9249,
#              'сме': 9246,
#              'ным': 9148,
#              'лет': 9069,
#              'ной': 9041,
#              'ная': 8982,
#              'гово': 8950,
#              'пред': 8948,
#              'сло': 8940,
#              'тель': 8921,
#              'дума': 8883,
#              'было': 8853,
#              'нии': 8849,
#              'тельно': 8652,
#              'очень': 8574,
#              'ров': 8527,
#              'нима': 8495,
#              'кто': 8467,
#              'нас': 8382,
#              'чу': 8323,
#              'лы': 8243,
#              'сно': 8237,
#              'чески': 8231,
#              'ющи': 8170,
#              'ге': 8146,
#              'фи': 8073,
#              'тому': 7995,
#              'ции': 7916,
#              'ства': 7892,
#              'тре': 7879,
#              'нам': 7784,
#              'зда': 7713,
#              'три': 7710,
#              'спо': 7640,
#              'вле': 7586,
#              'всё': 7513,
#              'ей': 7468,
#              'сказа': 7402,
#              'зу': 7273,
#              'ща': 7200,
#              'пло': 7189,
#              'ят': 7178,
#              'сдела': 7173,
#              'сту': 7130,
#              'боле': 7045,
#              'поль': 7039,
#              'работа': 7028,
#              'ний': 7000,
#              'лове': 7000,
#              'пы': 6969,
#              'стви': 6962,
#              'само': 6938,
#              'стро': 6773,
#              'мя': 6739,
#              'много': 6704,
#              'потому': 6687,
#              'челове': 6628,
#              'жиз': 6598,
#              'кой': 6590,
#              'смех': 6574,
#              'только': 6561,
#              'виде': 6506,
#              'ете': 6438,
#              'мер': 6427,
#              'фор': 6413,
#              'созда': 6377,
#              'смо': 6357,
#              'слу': 6343,
#              'пла': 6293,
#              'лись': 6289,
#              'зи': 6286,
#              'был': 6274,
#              'зыва': 6271,
#              'чем': 6256,
#              'лось': 6237,
#              'ются': 6218,
#              'может': 6208,
#              'нет': 6204,
#              'пока': 6161,
#              'рова': 6158,
#              'вно': 6115,
#              'логи': 6106,
#              'ную': 6104,
#              'дет': 6099,
#              'фе': 6083,
#              'после': 6051,
#              'ха': 5963,
#              'того': 5960,
#              'просто': 5912,
#              'полу': 5868,
#              'жен': 5847,
#              'вам': 5834,
#              'тра': 5833,
#              'которо': 5800,
#              'нача': 5789,
#              'кти': 5775,
#              'инте': 5716,
#              'больше': 5696,
#              'таки': 5684,
#              'исполь': 5665,
#              'бле': 5649,
#              'лся': 5620,
#              'образ': 5607,
#              'возможно': 5574,
#              'быть': 5566,
#              'тех': 5565,
#              'ству': 5555,
#              'шо': 5529,
#              'соб': 5517,
#              'тем': 5509,
#              'людей': 5496,
#              'ём': 5480,
#              'обще': 5474,
#              'мени': 5461,
#              'год': 5438,
#              'стоя': 5389,
#              'говори': 5372,
#              'тов': 5360,
#              'спе': 5356,
#              'кра': 5339,
#              'ут': 5336,
#              'каж': 5305,
#              'пол': 5293,
#              'ней': 5261,
#              'вой': 5214,
#              'им': 5190,
#              'этого': 5149,
#              'ными': 5148,
#              'дь': 5125,
#              'щё': 5114,
#              'ца': 5113,
#              'люди': 5102,
#              'более': 5092,
#              'гла': 5052,
#              'дин': 5049,
#              'этот': 5013,
#              'них': 5013,
#              'вя': 4958,
#              'где': 4946,
#              'менты': 4931,
#              'были': 4917,
#              'ков': 4899,
#              'нные': 4899,
#              'этом': 4861,
#              'ёт': 4854,
#              'кры': 4748,
#              'который': 4742,
#              'име': 4698,
#              'шь': 4691,
#              'час': 4672,
#              'прави': 4662,
#              'ещё': 4655,
#              'дис': 4628,
#              'исто': 4615,
#              'зде': 4615,
#              'пробле': 4593,
#              'время': 4574,
#              'сей': 4567,
#              'была': 4525,
#              'ческо': 4503,
#              'теле': 4489,
#              'дер': 4464,
#              'сре': 4446,
#              'деле': 4445,
#              'вз': 4437,
#              'вас': 4434,
#              'ход': 4429,
#              'нию': 4427,
#              'нных': 4408,
#              'други': 4393,
#              'вто': 4383,
#              'ью': 4383,
#              'лли': 4378,
#              'ция': 4373,
#              'наше': 4362,
#              'кру': 4358,
#              'помо': 4347,
#              'мой': 4328,
#              'буду': 4323,
#              'гу': 4309,
#              'сколько': 4298,
#              'сейчас': 4295,
#              'кт': 4258,
#              'оста': 4251,
#              'здесь': 4249,
#              'бя': 4248,
#              'вет': 4247,
#              'види': 4230,
#              'сы': 4229,
#              'её': 4198,
#              'можем': 4178,
#              'ного': 4157,
#              'нием': 4155,
#              'будет': 4153,
#              'действи': 4136,
#              'пример': 4124,
#              'ром': 4114,
#              'луч': 4099,
#              'этому': 4079,
#              'спа': 4069,
#              'уже': 4066,
#              'даже': 4065,
#              'жу': 4065,
#              'хоро': 4055,
#              'лась': 4013,
#              'клю': 3979,
#              'наши': 3977,
#              'там': 3977,
#              'предста': 3969,
#              'хи': 3960,
#              'нее': 3953,
#              'плодис': 3952,
#              'плодисменты': 3946,
#              'произ': 3935,
#              'чита': 3929,
#              'кар': 3899,
#              'фо': 3897,
#              'вопро': 3896,
#              'вые': 3883,
#              'дова': 3879,
#              'жде': 3872,
#              'фа': 3865,
#              'нужно': 3851,
#              'рии': 3835,
#              'аплодисменты': 3834,
#              'нт': 3833,
#              'йте': 3816,
#              'юще': 3806,
#              'жны': 3802,
#              'нов': 3801,
#              'года': 3793,
#              'иде': 3784,
#              'явля': 3765,
#              'суще': 3743,
#              'стью': 3738,
#              'этой': 3727,
#              'обра': 3717,
#              'гля': 3716,
#              'тер': 3699,
#              'одна': 3685,
#              'дви': 3674,
#              'жда': 3656,
#              'ника': 3647,
#              'друго': 3630,
#              'образо': 3597,
#              'рез': 3569,
#              'дно': 3555,
#              'один': 3553,
#              'рая': 3550,
#              'гру': 3549,
#              'поз': 3547,
#              'аль': 3544,
#              'нной': 3541,
#              'систе': 3539,
#              'сделать': 3534,
#              'эта': 3527,
#              'вме': 3512,
#              'коне': 3484,
#              'милли': 3484,
#              'кла': 3482,
#              'вали': 3481,
#              'стре': 3478,
#              'чему': 3475,
#              'свя': 3453,
#              'бли': 3452,
#              'поня': 3448,
#              'также': 3436,
#              'ально': 3427,
#              'тя': 3420,
#              'вра': 3411,
#              'поло': 3411,
#              'жизни': 3398,
#              'всего': 3382,
#              'объ': 3337,
#              'вели': 3330,
#              'могут': 3329,
#              'вый': 3316,
#              'ровать': 3279,
#              'ар': 3278,
#              'использо': 3260,
#              'кое': 3259,
#              'шу': 3247,
#              'учи': 3240,
#              'себя': 3212,
#              'ходит': 3200,
#              'вых': 3186,
#              'нный': 3178,
#              'кро': 3177,
#              'ном': 3163,
#              'ан': 3161,
#              'день': 3158,
#              'чего': 3157,
#              'годня': 3146,
#              'сегодня': 3142,
#              'ное': 3132,
#              'перь': 3128,
#              'форма': 3128,
#              'чь': 3127,
#              'вить': 3126,
#              'лё': 3124,
#              'теперь': 3108,
#              'нологи': 3085,
#              'хоте': 3084,
#              'этих': 3079,
#              'вая': 3040,
#              'дов': 3031,
#              'технологи': 3027,
#              'больши': 3018,
#              'осно': 3014,
#              'следова': 3004,
#              'интере': 3000,
#              'цию': 2992,
#              'бра': 2988,
#              'менно': 2985,
#              'поэтому': 2979,
#              'доста': 2979,
#              'которая': 2966,
#              'орга': 2965,
#              'уча': 2963,
#              'пыта': 2949,
#              'почему': 2937,
#              'проце': 2928,
#              'чина': 2911,
#              'дели': 2908,
#              'женщи': 2906,
#              'способ': 2904,
#              'кого': 2901,
#              'чув': 2899,
#              'проис': 2896,
#              'жду': 2893,
#              'многи': 2891,
#              'горо': 2890,
#              'можете': 2879,
#              'каза': 2866,
#              'рь': 2866,
#              'тру': 2865,
#              'эко': 2865,
#              'получи': 2864,
#              'чение': 2861,
#              'самы': 2861,
#              'нер': 2847,
#              'дом': 2839,
#              'спаси': 2837,
#              'над': 2830,
#              'йти': 2825,
#              'спасибо': 2813,
#              'зад': 2810,
#              'зе': 2809,
#              'случа': 2807,
#              'стру': 2802,
#              'всех': 2799,
#              'думаю': 2793,
#              'должны': 2793,
#              'зем': 2787,
#              'позво': 2787,
#              'самом': 2780,
#              'сказать': 2772,
#              'ственно': 2763,
#              'дя': 2761,
#              'послед': 2760,
#              'писа': 2757,
#              'цы': 2756,
#              'води': 2752,
#              'голо': 2747,
#              'осо': 2743,
#              'рт': 2737,
#              'большо': 2733,
#              'кажды': 2730,
#              'точно': 2720,
#              'вос': 2706,
#              'следу': 2703,
#              'бира': 2698,
#              'хочу': 2692,
#              'понима': 2687,
#              'которых': 2685,
#              'прое': 2652,
#              'через': 2635,
#              'моз': 2610,
#              'счита': 2610,
#              'доб': 2609,
#              'чтото': 2606,
#              'эк': 2605,
#              'ющих': 2599,
#              'сов': 2595,
#              'эту': 2594,
#              'жизнь': 2578,
#              'стано': 2567,
#              'тия': 2559,
#              'жения': 2558,
#              'сказал': 2554,
#              'графи': 2552,
#              'показа': 2548,
#              'ступ': 2543,
#              'между': 2542,
#              'без': 2542,
#              'него': 2540,
#              'исследова': 2539,
#              'откры': 2536,
#              'вания': 2536,
#              'заме': 2535,
#              'мате': 2534,
#              'кре': 2530,
#              'вое': 2529,
#              'назад': 2528,
#              'сни': 2524,
#              'называ': 2523,
#              'разви': 2522,
#              'поли': 2514,
#              'лучше': 2514,
#              'органи': 2493,
#              'мир': 2482,
#              'действительно': 2478,
#              'бла': 2477,
#              'чё': 2465,
#              'жение': 2462,
#              'кан': 2461,
#              'тей': 2453,
#              'могли': 2452,
#              'несколько': 2448,
#              'доро': 2446,
#              'зада': 2437,
#              'реше': 2436,
#              'вает': 2433,
#              'еди': 2429,
#              'информа': 2424,
#              'ности': 2423,
#              'итак': 2420,
#              'тро': 2406,
#              'использу': 2402,
#              'отно': 2394,
#              'сси': 2379,
#              'сла': 2377,
#              'каждый': 2377,
#              'истори': 2368,
#              'шло': 2362,
#              'конечно': 2362,
#              'посмо': 2353,
#              'ющие': 2352,
#              'нения': 2352,
#              'именно': 2345,
#              'сты': 2341,
#              'два': 2336,
#              'делать': 2325,
#              'мент': 2321,
#              'значи': 2315,
#              'вал': 2310,
#              'себе': 2306,
#              'слы': 2304,
#              'мери': 2304,
#              'юсь': 2294,
#              'опре': 2290,
#              'видите': 2273,
#              'ять': 2267,
#              'грам': 2265,
#              'эле': 2263,
#              'человек': 2253,
#              'вод': 2250,
#              'всем': 2247,
#              'тить': 2245,
#              'ему': 2244,
#              'обы': 2244,
#              'мире': 2243,
#              'реши': 2235,
#              'кли': 2224,
#              'сторо': 2221,
#              'кри': 2219,
#              'этим': 2206,
#              'ним': 2205,
#              'рую': 2202,
#              'вь': 2195,
#              'лле': 2195,
#              'году': 2187,
#              'бой': 2184,
#              'цен': 2183,
#              'номи': 2177,
#              'обе': 2176,
#              'вши': 2174,
#              'тогда': 2169,
#              'кую': 2168,
#              'коло': 2167,
#              'стои': 2167,
#              'стя': 2164,
#              'отве': 2157,
#              'сред': 2154,
#              'щу': 2151,
#              'дава': 2146,
#              'кие': 2143,
#              'нами': 2132,
#              'льта': 2131,
#              'является': 2128,
#              'ман': 2126,
#              'фото': 2125,
#              'видеть': 2109,
#              'например': 2105,
#              'аф': 2090,
#              'веро': 2088,
#              'комп': 2087,
#              'точ': 2086,
#              'важно': 2084,
#              'измени': 2079,
#              'часть': 2076,
#              'вли': 2071,
#              'вают': 2064,
#              'хорошо': 2064,
#              'пря': 2062,
#              'времени': 2058,
#              'простра': 2057,
#              'мира': 2055,
#              'поч': 2055,
#              'амери': 2051,
#              'верх': 2047,
#              'уди': 2045,
#              'изме': 2040,
#              'чения': 2037,
#              'компа': 2036,
#              'кту': 2034,
#              'жить': 2033,
#              'затем': 2030,
#              'шко': 2029,
#              'нта': 2028,
#              'вопрос': 2028,
#              'вне': 2023,
#              'тно': 2022,
#              'экономи': 2019,
#              'ких': 2013,
#              'емся': 2012,
#              'одно': 2011,
#              'необ': 2007,
#              'хра': 1996,
#              'ления': 1994,
#              'чество': 1993,
#              'вание': 1986,
#              'нару': 1983,
#              'получа': 1978,
#              'ник': 1977,
#              'существу': 1975,
#              'обла': 1972,
#              'резу': 1971,
#              'результа': 1968,
#              'обо': 1962,
#              'нем': 1959,
#              'нная': 1957,
#              'мас': 1954,
#              'энер': 1953,
#              'мале': 1952,
#              'ог': 1948,
#              'ответ': 1946,
#              'треть': 1946,
#              'блю': 1943,
#              'сем': 1941,
#              'наш': 1935,
#              'нау': 1933,
#              'тво': 1918,
#              'могу': 1914,
#              'вро': 1913,
#              'ческие': 1912,
#              'уда': 1906,
#              'нным': 1905,
#              'происходит': 1904,
#              'све': 1903,
#              'авто': 1902,
#              'проси': 1899,
#              'ской': 1898,
#              'дать': 1898,
#              'пом': 1895,
#              'необходи': 1895,
#              'образом': 1893,
#              'пор': 1889,
#              'потом': 1888,
#              'малень': 1886,
#              'совер': 1881,
#              'всегда': 1880,
#              'маши': 1880,
#              'телей': 1878,
#              'ющий': 1874,
#              'прав': 1870,
#              'которой': 1870,
#              'сс': 1867,
#              'нство': 1866,
#              'оно': 1865,
#              'начина': 1864,
#              'тив': 1864,
#              'кая': 1861,
#              'мень': 1855,
#              'ках': 1853,
#              'свои': 1847,
#              'вероят': 1843,
#              'компью': 1842,
#              'био': 1842,
#              'теля': 1838,
#              'тели': 1824,
#              'груп': 1820,
#              'знаете': 1812,
#              'наде': 1811,
#              'нци': 1810,
#              'которое': 1807,
#              'шта': 1806,
#              'вну': 1805,
#              'вести': 1798,
#              'ваться': 1796,
#              'друг': 1790,
#              'таким': 1789,
#              'програм': 1785,
#              'помощ': 1782,
#              'ность': 1781,
#              'интер': 1779,
#              'ёл': 1777,
#              'ческих': 1775,
#              'никогда': 1774,
#              'дель': 1774,
#              'вместе': 1774,
#              'игра': 1772,
#              'крас': 1770,
#              'пар': 1769,
#              'человека': 1767,
#              'которую': 1766,
#              'той': 1763,
#              'такие': 1752,
#              'вится': 1750,
#              'нить': 1749,
#              'щая': 1741,
#              'некоторые': 1735,
#              'других': 1731,
#              'высо': 1730,
#              'продол': 1729,
#              'ками': 1725,
#              'лич': 1724,
#              'находи': 1724,
#              'детей': 1722,
#              'ья': 1721,
#              'муж': 1719,
#              'подума': 1715,
#              'цев': 1712,
#              'занима': 1711,
#              'род': 1703,
#              'коли': 1702,
#              'тыся': 1702,
#              'сер': 1699,
#              'нашей': 1696,
#              'дово': 1695,
#              'пове': 1693,
#              'глу': 1692,
#              'зву': 1688,
#              'кни': 1688,
#              'хоти': 1684,
#              'нк': 1679,
#              'нтов': 1679,
#              'разу': 1677,
#              'такой': 1671,
#              'мента': 1671,
#              'проблема': 1665,
#              'музы': 1663,
#              'другой': 1661,
#              'нд': 1659,
#              'моя': 1657,
#              'либо': 1657,
#              'вого': 1651,
#              'ходя': 1651,
#              'будут': 1651,
#              'нное': 1649,
#              'ческой': 1648,
#              'рю': 1645,
#              'ключа': 1643,
#              'нуть': 1640,
#              'приме': 1637,
#              'поте': 1635,
#              'матери': 1632,
#              'кор': 1632,
#              'афри': 1629,
#              'расска': 1627,
#              'гре': 1625,
#              'говоря': 1620,
#              'тря': 1619,
#              'настоя': 1618,
#              'давайте': 1615,
#              'своей': 1609,
#              'сами': 1608,
#              'многие': 1606,
#              'будь': 1603,
#              'собира': 1602,
#              'шая': 1602,
#              'тот': 1596,
#              'полити': 1593,
#              'роди': 1592,
#              'мар': 1590,
#              'ская': 1587,
#              'лом': 1582,
#              'ффе': 1582,
#              'дву': 1581,
#              'перед': 1580,
#              'части': 1577,
#              'энерги': 1577,
#              'принима': 1575,
#              'дости': 1573,
#              'ских': 1572,
#              'свою': 1572,
#              'важ': 1571,
#              'дра': 1567,
#              'ничего': 1566,
#              'нали': 1566,
#              'цу': 1564,
#              'плане': 1563,
#              'рой': 1561,
#              'выгля': 1560,
#              'ран': 1554,
#              'тор': 1553,
#              'лишь': 1552,
#              'ств': 1552,
#              'нного': 1548,
#              'использовать': 1547,
#              'бор': 1543,
#              'вления': 1543,
#              'рения': 1538,
#              'достаточно': 1538,
#              'стоит': 1537,
#              'стей': 1532,
#              'вещи': 1532,
#              'долла': 1526,
#              'стал': 1523,
#              'узна': 1520,
#              'ню': 1513,
#              'моей': 1512,
#              'емы': 1511,
#              'поя': 1508,
#              'правля': 1508,
#              'фу': 1507,
#              'эффе': 1505,
#              'цо': 1501,
#              'зай': 1500,
#              'пара': 1500,
#              'соци': 1499,
#              'встре': 1498,
#              'изве': 1497,
#              'дой': 1495,
#              'отноше': 1495,
#              'жется': 1494,
#              'вами': 1493,
#              'спу': 1492,
#              'строи': 1491,
#              'ск': 1489,
#              'работать': 1489,
#              'лага': 1489,
#              'ческий': 1488,
#              'немного': 1485,
#              'надо': 1485,
#              'куль': 1485,
#              'наз': 1483,
#              'фотографи': 1477,
#              'ток': 1476,
#              'мест': 1475,
#              'реа': 1474,
#              'кта': 1472,
#              'подоб': 1468,
#              'будуще': 1465,
#              'около': 1464,
#              'мати': 1464,
#              'еще': 1461,
#              'наших': 1461,
#              'ского': 1461,
#              'кий': 1458,
#              'знаю': 1455,
#              'вается': 1454,
#              'мет': 1454,
#              'дёт': 1453,
#              'рен': 1451,
#              'грани': 1448,
#              'идея': 1446,
#              'дж': 1445,
#              'внима': 1445,
#              'ваше': 1445,
#              'ники': 1445,
#              'инди': 1443,
#              'потре': 1442,
#              'вление': 1441,
#              'дё': 1440,
#              'такое': 1440,
#              'дли': 1439,
#              'бро': 1438,
#              'тие': 1437,
#              'говорить': 1437,
#              'миллио': 1433})

# %%
print(len(vocab))
# Out:
# 1000

# %%
def build_token_mappings(vocab):
    tokens = list(vocab.keys())
    token_to_id = {token: idx for idx, token in enumerate(tokens)}
    id_to_token = {idx: token for idx, token in enumerate(tokens)}
    return token_to_id, id_to_token

token_to_id, id_to_token = build_token_mappings(vocab)

# %%
def add_special_tokens(token_to_id, id_to_token, special_tokens):
    for token in special_tokens:
        if token not in token_to_id:
            idx = len(token_to_id)
            token_to_id[token] = idx
            id_to_token[idx] = token

special_tokens = ['<start>', '<end>', '<unk>', '<pad>']
add_special_tokens(token_to_id, id_to_token, special_tokens)

print(f"\nДобавлены специальные токены. Размер словаря token_to_id: {len(token_to_id)}")
# Out:
# Добавлены специальные токены. Размер словаря token_to_id: 1004

# %%
import json
import os

output_dir = "C:/Tokenizer/Vocab/RuVocab" 

os.makedirs(output_dir, exist_ok=True)

with open(os.path.join(output_dir, 'token_to_id.json'), 'w', encoding='utf-8') as out_file:
    json.dump(token_to_id, out_file, indent=6, ensure_ascii=False)

with open(os.path.join(output_dir, 'id_to_token.json'), 'w', encoding='utf-8') as out_file:
    json.dump(id_to_token, out_file, indent=6, ensure_ascii=False)

print(f"Словари token_to_id и id_to_token сохранены в {output_dir}")
# Out:
# Словари token_to_id и id_to_token сохранены в C:/Tokenizer/Vocab/RuVocab

# %%
def tokenize_word(word, vocab):
    symbols = list(word) + ['_ed']  
    i = 0
    tokens = []
    while i < len(symbols):
        j = len(symbols)
        found = False
        while j > i:
            substring = ''.join(symbols[i:j])
            if substring in vocab:
                tokens.append(substring)
                i = j
                found = True
                break
            else:
                j -= 1
        if not found:
            tokens.append('<unk>')
            i += 1
    return tokens

# %%
def encode_text(text, token_to_id, vocab):
    token_ids = []
    for word in text.split():
        word_tokens = tokenize_word(word, vocab)
        for token in word_tokens:
            token_id = token_to_id.get(token)
            if token_id is not None:
                token_ids.append(token_id)
            else:
                token_ids.append(token_to_id.get('<unk>'))
    return token_ids

# %%
def decode_ids(token_ids, id_to_token):
    tokens = [id_to_token.get(token_id, '<unk>') for token_id in token_ids]
    words = []
    word = ''
    for token in tokens:
        if token == '_ed':
            words.append(word)
            word = ''
        elif token not in ['<start>', '<end>', '<pad>']:
            word += token
    if word:
        words.append(word)
    return ' '.join(words)

# %%
test_text = "Я учусь в техническом вузе, чтобы стать программистом"
test_text = clean_text(test_text)

# %%
encoded_ids = encode_text(test_text, token_to_id, vocab)
print("\nКодированные идентификаторы:")
print(encoded_ids)
# Out:
# Кодированные идентификаторы:
# [0, 1, 3, 238, 105, 1, 14, 1, 324, 38, 378, 4, 1, 165, 566, 1, 190, 1, 95, 49, 1, 821, 68, 98, 4, 1]

# %%
decoded_text = decode_ids(encoded_ids, id_to_token)
print("\nДекодированный текст:")
print(decoded_text)
# Out:
# Декодированный текст:
# я учусь в техническом вузе чтобы стать программистом
